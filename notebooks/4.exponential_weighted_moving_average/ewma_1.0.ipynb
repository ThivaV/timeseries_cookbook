# %% [markdown]
# # Exponential Weighted Moving Average (EWMA)

# %%
import pandas as pd                         # type: ignore
import pandas_datareader.data as web        # type: ignore
import matplotlib.pyplot as plt             # type: ignore
# %matplotlib inline

from datetime import datetime as dt

# %%
df_tesla = web.DataReader('TSLA', 'stooq')
len(df_tesla), df_tesla.columns
# Out:
# (1256, Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object'))

# %%
df_tesla
# Out:
#                 Open      High       Low     Close     Volume
# Date
# 2024-07-26  221.1900  222.2799  215.3300  219.8000   94604145
# 2024-07-25  216.8000  226.0000  216.2310  220.2500  100636466
# 2024-07-24  225.4200  225.9900  214.7100  215.9900  167942939
# 2024-07-23  253.6000  255.7594  245.6300  246.3800  111928192
# 2024-07-22  244.2100  253.2100  243.7500  251.5100  101225430
# ...              ...       ...       ...       ...        ...
# 2019-08-06   15.4587   15.5000   15.0500   15.3833   83463000
# 2019-08-05   15.3067   15.4243   15.0517   15.2213  105424185
# 2019-08-02   15.4233   15.7513   15.2820   15.6227   92047215
# 2019-08-01   16.1767   16.3007   15.4513   15.5900  123892740
# 2019-07-31   16.2000   16.4453   15.7767   16.1073  137673120
#
# [1256 rows x 5 columns]

# %%
# EWMA
# span is the smoothinner
df_tesla['EWMA_5'] = df_tesla['Open'].ewm(span=5).mean()

# %%
df_tesla[['Open', 'EWMA_5']].plot(figsize=(20, 5))
# Out:
# <Axes: xlabel='Date'>

# %%
# span is the smoothinner = 10
df_tesla['EWMA_10'] = df_tesla['Open'].ewm(span=10).mean()

# %%
df_tesla[['Open', 'EWMA_5', 'EWMA_10']].plot(figsize=(20, 5))
# Out:
# <Axes: xlabel='Date'>
